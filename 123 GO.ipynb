# %%
import sqlite3
! pip install pandas 
import pandas as pd

# %%
df=pd.read_csv('owid-covid-data.csv')

# %%
df.to_sql('covid',sqlite3.connect("covid.db"), if_exists='append',index = False)

# %%
conn = sqlite3.connect('soccer.sqlite')

# %%
conn = sqlite3.connect("covid.db")

# %%
df = pd.read_sql_query("SELECT * FROM covid_data", conn)
df
# Out:
#       iso_code continent     location        date total_cases new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24         1.0       1.0
# 1          AFG      Asia  Afghanistan  2020-02-25         1.0       0.0
# 2          AFG      Asia  Afghanistan  2020-02-26         1.0       0.0
# 3          AFG      Asia  Afghanistan  2020-02-27         1.0       0.0
# 4          AFG      Asia  Afghanistan  2020-02-28         1.0       0.0
# ...        ...       ...          ...         ...         ...       ...
# 86413      ZWE    Africa     Zimbabwe  2021-05-02     38281.0      21.0
# 86414      ZWE    Africa     Zimbabwe  2021-05-03     38293.0      12.0
# 86415      ZWE    Africa     Zimbabwe  2021-05-04     38327.0      34.0
# 86416      ZWE    Africa     Zimbabwe  2021-05-05     38357.0      30.0
# 86417      ZWE    Africa     Zimbabwe  2021-05-06     38398.0      41.0
#
#       new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# ### 1 Combien de pays sont inclus dans notre ensemble de données?
# ### How many countries are included in our data set?

# %%
df = pd.read_sql_query("SELECT * FROM covid_data ", conn)
df
# Out:
#       iso_code continent     location        date total_cases new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24         1.0       1.0
# 1          AFG      Asia  Afghanistan  2020-02-25         1.0       0.0
# 2          AFG      Asia  Afghanistan  2020-02-26         1.0       0.0
# 3          AFG      Asia  Afghanistan  2020-02-27         1.0       0.0
# 4          AFG      Asia  Afghanistan  2020-02-28         1.0       0.0
# ...        ...       ...          ...         ...         ...       ...
# 86413      ZWE    Africa     Zimbabwe  2021-05-02     38281.0      21.0
# 86414      ZWE    Africa     Zimbabwe  2021-05-03     38293.0      12.0
# 86415      ZWE    Africa     Zimbabwe  2021-05-04     38327.0      34.0
# 86416      ZWE    Africa     Zimbabwe  2021-05-05     38357.0      30.0
# 86417      ZWE    Africa     Zimbabwe  2021-05-06     38398.0      41.0
#
#       new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# ### 2 When was the most recent entry?
# ### A quand remonte la plus recente?

# %%
df = pd.read_sql_query("SELECT date FROM covid_data ORDER BY date ", conn)
df
# Out:
#              date
# 0      2020-01-01
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-02
# 4      2020-01-03
# ...           ...
# 86413  2021-05-06
# 86414  2021-05-06
# 86415  2021-05-06
# 86416  2021-05-06
# 86417  2021-05-06
#
# [86418 rows x 1 columns]

# %%
df = pd.read_sql_query("SELECT date FROM covid_data ORDER BY date DESC LIMIT 1 ", conn)
df
# Out:
#          date
# 0  2021-05-06

# %% [markdown]
# ### 3 Quel est le pays qui a enregistré le plus grand nombre de décès par million?
# ### What country had the highest single day deaths per million?

# %%
df = pd.read_sql_query("SELECT location FROM covid_data DESC", conn)
df
# Out:
#           location
# 0      Afghanistan
# 1      Afghanistan
# 2      Afghanistan
# 3      Afghanistan
# 4      Afghanistan
# ...            ...
# 86413     Zimbabwe
# 86414     Zimbabwe
# 86415     Zimbabwe
# 86416     Zimbabwe
# 86417     Zimbabwe
#
# [86418 rows x 1 columns]

# %%
df = pd.read_sql_query("SELECT location FROM covid_data ORDER BY new_deaths_per_million DESC LIMIT 1", conn)
df
# Out:
#   location
# 0  Austria

# %% [markdown]
# ### 1 Select any country. How many times have the deaths per million exceeded 1,000 in one day?
# ### Choisissez un pays. Combien de fois le nombre de décès par million a-t-il dépassé 1 000 en une journée?

# %%
df = pd.read_sql_query("SELECT COUNT(*) FROM covid_data WHERE new_deaths_per_million > 1000",conn)
df
# Out:
#    COUNT(*)
# 0     14438

# %%
df = pd.read_sql_query("SELECT location,new_deaths_per_million FROM covid_data WHERE new_deaths_per_million > 1000",conn)
df
# Out:
#        location new_deaths_per_million
# 0       Albania                  2.085
# 1       Albania                  2.085
# 2       Albania                  2.085
# 3       Albania                  2.085
# 4       Albania                  2.085
# ...         ...                    ...
# 14433  Zimbabwe                  2.557
# 14434  Zimbabwe                  3.028
# 14435  Zimbabwe                  2.086
# 14436  Zimbabwe                   4.71
# 14437  Zimbabwe                  2.557
#
# [14438 rows x 2 columns]

# %% [markdown]
# # Extract the deaths per million for US, France, and India. Plot the time series data and compare results to what the media is currently saying
# # Extraire les décès par million pour les États-Unis, la France et l’Inde. Tracer les données des séries chronologiques et comparer les résultats à ce que les médias disent actuellement

# %%
df = pd.read_sql_query("SELECT new_deaths_per_million, location FROM covid_data WHERE location IN ('France', 'India', 'United States') ORDER BY date ASC;", conn)
df
# Out:
#      new_deaths_per_million       location
# 0                            United States
# 1                            United States
# 2                                   France
# 3                            United States
# 4                                   France
# ...                     ...            ...
# 1398                  2.884          India
# 1399                  2.344  United States
# 1400                  3.214         France
# 1401                    0.0          India
# 1402                  2.375  United States
#
# [1403 rows x 2 columns]

# %%
# rajoute une colonne date  dans le df  ??
#df= pd.read_sql_query("SELECT new_deaths_per_million, new_cases_per_million, continent, date FROM covid_data WHERE date; ",conn)

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(26,10))
sns.set_context("paper", font_scale=2.5, rc={"lines.linewidth": 3.5})
plt.rcParams['figure.dpi'] = 360
sns.lineplot(data=df, x="date", y="new_deaths_per_million", hue = 'location')
plt.xlabel("date") 
plt.ylabel("new_deaths_per_million") 
plt.title("Evolution of covid deaths per million")
horizontalalignment='right'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-c1c887585de2> in <module>
#       2 sns.set_context("paper", font_scale=2.5, rc={"lines.linewidth": 3.5})
#       3 plt.rcParams['figure.dpi'] = 360
# ----> 4 sns.lineplot(data=df, x="date", y="new_deaths_per_million", hue = 'location')
#       5 plt.xlabel("date")
#       6 plt.ylabel("new_deaths_per_million")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
time_series_countries['date'] = time_series_countries['date'].astype(dtype='datetime64[ns]')
tu remplace time_series_countries par le nom de ton dataframe
